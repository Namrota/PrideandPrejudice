# %% [markdown]
# <a href="https://colab.research.google.com/github/Namrota/PrideandPrejudice/blob/main/Python'S_Counter_with_Pride_and_Prejudice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
from bs4 import BeautifulSoup
import requests
import re
from collections import Counter

# Fetch the pages
url = 'https://www.gutenberg.org/cache/epub/1342/pg1342-images.html'
response = requests.get(url)

# Check the status code
if response.status_code == 200:
    content = response.text
    soup = BeautifulSoup(content, 'lxml')

    # Find paragraphs with class "nind"
    elements = soup.find_all("p", class_="nind")

    paragraphs = []
    for element in elements:
        # Extract the text from each element
        text = element.get_text()
        # Clean the text
        text = text.strip().replace('\n', ' ')
        paragraphs.append(text.split())

    # Unpack the list into individual words
    words = [word.capitalize() for paragraph in paragraphs for word in paragraph]

    # Clean the words further
    cleaned_list = [re.sub("[.,;?:\"\\-”“—’]*?", "", word) for word in words]

    # Create a Counter object
    word_counts = Counter(cleaned_list)

    # Print word frequencies
    for word, count in word_counts.items():
        print(f"{word}: {count}")
else:
    print("Failed to fetch the content.")
# Out:
# It: 79
# Is: 5
# A: 133
# Truth: 3
# Universally: 1
# Acknowledged: 1
# That: 84
# Single: 3
# Man: 6
# In: 148
# Possession: 4
# Of: 293
# Good: 11
# Fortune: 4
# Must: 14
# Be: 63
# Want: 3
# Wife: 8
# R: 7
# Bennet: 24
# Was: 160
# Among: 2
# The: 411
# Earliest: 2
# Those: 6
# Who: 14
# Waited: 4
# On: 51
# Mr: 67
# Bingley: 19
# He: 95
# Had: 132
# Always: 5
# Intended: 1
# To: 276
# Visit: 13
# Him: 57
# Though: 12
# Last: 6
# Assuring: 1
# His: 116
# Should: 10
# Not: 65
# Go: 2
# And: 268
# Till: 6
# Evening: 6
# After: 20
# Paid: 2
# She: 115
# No: 25
# Knowledge: 2
# Then: 10
# Disclosed: 1
# Following: 4
# Manner: 8
# Observing: 3
# Second: 5
# Daughter: 9
# Employed: 2
# Trimming: 1
# Hat: 1
# Suddenly: 2
# Addressed: 2
# Her: 162
# With: 78
# Ot: 1
# All: 39
# Mrs: 21
# However: 10
# Assistance: 1
# Five: 6
# Daughters: 5
# Could: 42
# Ask: 2
# Subject: 4
# Sufficient: 1
# Draw: 1
# From: 47
# Husband: 6
# Any: 17
# Satisfactory: 2
# Description: 1
# They: 47
# ...

# %%
# Getting the most common words:
word_counts.most_common(70)
# Out:
# [('The', 411),
#  ('Of', 293),
#  ('To', 276),
#  ('And', 268),
#  ('Her', 162),
#  ('Was', 160),
#  ('In', 148),
#  ('A', 133),
#  ('Had', 132),
#  ('His', 116),
#  ('She', 115),
#  ('He', 95),
#  ('That', 84),
#  ('For', 81),
#  ('It', 79),
#  ('With', 78),
#  ('As', 70),
#  ('Mr', 67),
#  ('Not', 65),
#  ('At', 64),
#  ('Be', 63),
#  ('Him', 57),
#  ('On', 51),
#  ('By', 51),
#  ('But', 50),
#  ('From', 47),
#  ('They', 47),
#  ('Were', 47),
#  ('Which', 47),
#  ('Could', 42),
#  ('Their', 41),
#  ('All', 39),
#  ('Elizabeth', 39),
#  ('Been', 37),
#  ('Them', 35),
#  ('Very', 33),
#  ('An', 33),
#  ('Such', 28),
#  ('Have', 28),
#  ('Jane', 27),
#  ('No', 25),
#  ('Before', 25),
#  ('Bennet', 24),
#  ('Would', 24),
#  ('What', 22),
#  ('Mrs', 21),
#  ('Or', 21),
#  ('After', 20),
#  ('Darcy', 20),
#  ('Herself', 20),
#  ('Than', 20),
#  ('Bingley', 19),
#  ('Time', 19),
#  ('Collins', 19),
#  ('When', 18),
#  ('This', 18),
#  ('Morning', 18),
#  ('Any', 17),
#  ('Lady', 17),
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Generate a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=70).generate_from_frequencies(word_counts)

# Display the WordCloud using Matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
